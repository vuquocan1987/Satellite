# %%
import pandas as pd
fp = "/home/an/Workspace/SateliteData/data/points_of_interest_10m.csv"
data = pd.read_csv(fp).values
for item in data:
    print(item)
# Out:
# [24.13044  65.918934]
# [24.090357 65.925954]
# [24.037013 65.965172]
# [23.718624 66.199689]
# [23.717337 66.2156  ]
# [23.691974 66.237346]
# [23.687682 66.254443]
# [23.647084 66.28408 ]
# [23.661933 66.303059]
# [23.652706 66.328728]
# [23.678198 66.375395]
# [23.649359 66.395818]
# [23.671031 66.461546]
# [23.735018 66.503279]
# [23.800936 66.543763]
# [23.859816 66.575277]
# [23.877926 66.611743]
# [23.863077 66.650826]
# [23.646011 67.107207]
# [23.550525 67.17917 ]
# [23.503618 67.19313 ]
# [23.408046 67.204207]
# [23.259301 67.25573 ]
# [22.771912 67.263743]
# [22.506223 67.430731]
# [22.353144 67.48826 ]
# [21.686883 67.680168]
# [21.660275 67.678913]
# [21.633239 67.678179]
# [21.621695 67.69475 ]
# [21.22992  67.731223]
# [20.64992 67.84291]
# [20.586877 67.84427 ]
# [20.513277 67.855095]
# [20.493279 67.864071]
# [20.36037  67.944237]
